# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Brand.csv')
print(df.head())
# Out:
#      Brand     Resolution  Size   Selling Price  Original Price  \
# 0  TOSHIBA   Ultra HD LED   55.0        37999.0         54990.0
# 1      NaN            NaN    NaN            NaN             NaN
# 2      NaN            NaN    NaN            NaN             NaN
# 3     TCL   QLED Ultra HD   55.0        52999.0        129990.0
# 4      NaN            NaN    NaN            NaN             NaN
#
#   Operating System  Rating
# 0            VIDAA     4.3
# 1              NaN     NaN
# 2              NaN     NaN
# 3          Android     4.4
# 4              NaN     NaN

# %%
print(df.info())
print(df.describe())

# %%
import seaborn as sns
plt.figure(figsize=(15, 8))
sns.countplot(data=df, x='Brand', order=df['Brand'].value_counts().index)
plt.title('Count of TVs by Brand')
plt.xlabel('Brand')
plt.ylabel('Count')
plt.xticks(rotation=90)
plt.show()

# %%
import seaborn as sns
plt.figure(figsize=(12, 6))
sns.countplot(data=df, x='Resolution', order=df['Resolution'].value_counts().index)
plt.title('Count of TVs by Resolution')
plt.xlabel('Resolution')
plt.ylabel('Count')
plt.xticks(rotation=90)
plt.show()
